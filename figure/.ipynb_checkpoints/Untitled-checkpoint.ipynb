# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np

# 설치된 폰트 출력
font_list = [font.name for font in fm.fontManager.ttflist]
font_list

# plt.rcParams['font.family'] = 'NanumSquare'
# Out:
# ['STIXSizeOneSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'cmex10',
#  'STIXSizeOneSym',
#  'cmsy10',
#  'STIXGeneral',
#  'STIXSizeFiveSym',
#  'cmmi10',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'DejaVu Sans',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif Display',
#  'cmtt10',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'STIXSizeThreeSym',
#  'cmss10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'cmr10',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'DejaVu Sans Mono',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Display',
#  'Corbel',
#  'Arial Rounded MT Bold',
#  'Cooper Black',
#  'HyhwpEQ',
#  'ESRI NIMA VMAP1&2 PT',
#  'ESRI NIMA City Graphic LN',
#  'Calisto MT',
#  'ESRI ERS Operations S1',
#  'Microsoft JhengHei',
#  'Engravers MT',
#  'Wingdings 2',
#  'MGungJeong',
#  'Microsoft Sans Serif',
#  'Freestyle Script',
#  'ESRI Surveyor',
#  'ESRI Mil2525C Modifiers',
#  'ESRI US Forestry 1',
#  'Garamond',
#  'Palatino Linotype',
#  'Courier New',
#  'Curlz MT',
#  'Ebrima',
#  'Niagara Solid',
#  'Bauhaus 93',
#  'Edwardian Script ITC',
#  'Forte',
#  'SimSun',
#  'Bradley Hand ITC',
#  'Comic Sans MS',
#  'Comic Sans MS',
#  'Rockwell',
#  'Gill Sans MT Condensed',
#  'Calisto MT',
#  'HYSinMyeongJo-Medium',
#  'Goudy Old Style',
#  'ESRI Enviro Hazard Incident',
#  'Lucida Sans Unicode',
#  'Segoe UI',
#  'Constantia',
#  'Bodoni MT',
#  'Goudy Stout',
#  'Pyunji R',
#  'Bookshelf Symbol 7',
#  'Georgia',
#  'KoPubBatang Light',
#  'Gill Sans MT',
#  'HYPost-Medium',
#  'Californian FB',
#  'Georgia',
#  'Vivaldi',
#  'Microsoft PhagsPa',
#  'Maiandra GD',
#  'ESRI ERS Infrastructures S1',
#  'Jokerman',
#  'Tahoma',
#  'Bodoni MT',
#  'Comic Sans MS',
#  'HYGothic-Medium',
#  'Arial',
#  'Rockwell Condensed',
#  'Corbel',
#  'Eras Light ITC',
#  'ESRI Caves 3',
#  'Trebuchet MS',
#  'Courier New',
#  'Snap ITC',
#  'Bookman Old Style',
#  'Wide Latin',
#  'ESRI NIMA DNC PT',
#  'ESRI AMFM Sewer',
#  'Lucida Bright',
#  'Microsoft YaHei',
#  'Eras Bold ITC',
#  'Rockwell',
#  'NanumSquare_ac',
#  'Imprint MT Shadow',
#  'Franklin Gothic Medium',
#  'ESRI Enviro Hazard Analysis',
#  'Myanmar Text',
#  'Book Antiqua',
#  'Javanese Text',
#  'Lucida Fax',
#  'Century Schoolbook',
#  'Britannic Bold',
#  'Gloucester MT Extra Condensed',
#  'Bookman Old Style',
#  'KoPubBatang Bold',
#  'Century Gothic',
#  'Calibri',
#  'Symbol',
#  'Copperplate Gothic Bold',
#  'Tw Cen MT Condensed',
#  'Times New Roman',
#  'Gigi',
#  'Courier New',
#  'ESRI Caves 2',
#  'Sitka Small',
#  'ESRI AMFM Water',
#  'Bell MT',
#  'ESRI MilRed 01',
#  'French Script MT',
#  'ESRI Ordnance Survey',
#  'Harrington',
#  'ESRI SDS 2.00 2',
#  'Segoe UI',
#  'MJemokBatang',
#  'Ebrima',
#  'ESRI Arrowhead',
#  'Franklin Gothic Demi',
#  'Microsoft YaHei',
#  'Castellar',
#  'High Tower Text',
#  'Franklin Gothic Heavy',
#  'Berlin Sans FB',
#  'KoPubDotum Light',
#  'Headline R',
#  'ESRI Dimensioning',
#  'ESRI Public1',
#  'Ravie',
#  'Viner Hand ITC',
#  'KoPubDotum Bold',
#  'Microsoft Yi Baiti',
#  'ESRI Enviro Hazard Sites',
#  'Nirmala UI',
#  'Book Antiqua',
#  'MDotum',
#  'Segoe UI',
#  'Verdana',
#  'Times New Roman',
#  'ESRI Hazardous Materials',
#  'Lucida Handwriting',
#  'Rockwell',
#  'Playbill',
#  'Papyrus',
#  'Candara',
#  'Microsoft Himalaya',
#  'Lucida Sans',
#  'Verdana',
#  'Franklin Gothic Book',
#  'Century Schoolbook',
#  'Copperplate Gothic Light',
#  'Tempus Sans ITC',
#  'Berlin Sans FB',
#  'Webdings',
#  'Bookman Old Style',
#  'HYPMokGak-Bold',
#  'Bodoni MT',
#  'Segoe UI',
#  'ESRI Commodities',
#  'ESRI NIMA DNC LN',
#  'Lucida Console',
#  'Consolas',
#  'Segoe UI',
#  'Gill Sans MT',
#  'Calibri',
#  'Eras Demi ITC',
#  'NanumSquare_ac',
#  'Corbel',
#  'HCR Batang Ext',
#  'Franklin Gothic Demi Cond',
#  'Perpetua',
#  'Franklin Gothic Heavy',
#  'Franklin Gothic Medium Cond',
#  'Segoe UI Symbol',
#  'Verdana',
#  'ESRI Environmental & Icons',
#  'Franklin Gothic Demi',
#  'Arial',
#  'Impact',
#  'Microsoft New Tai Lue',
#  'Trebuchet MS',
#  'Trebuchet MS',
#  'Perpetua Titling MT',
#  'Bernard MT Condensed',
#  'Yu Gothic',
#  'Mistral',
#  'ESRI Elements',
#  'Century Schoolbook',
#  'Bell MT',
#  'Bodoni MT',
#  'HCR Dotum',
#  'Courier New',
#  'Elephant',
#  'Segoe UI Historic',
#  'Century Schoolbook',
#  'Cambria',
#  'HYGothic-Extra',
#  'NanumSquare_ac',
#  'ESRI Geology USGS 95-525',
#  'Constantia',
#  'HCR Batang',
#  'Microsoft JhengHei',
#  'Microsoft PhagsPa',
#  'Candara',
#  'KoPubDotum Medium',
#  'HCR Dotum Ext',
#  'ESRI IGL Font23',
#  'Arial',
#  'Georgia',
#  'Bodoni MT',
#  'Chiller',
#  'Informal Roman',
#  'Bodoni MT',
#  'ESRI NIMA VMAP1&2 LN',
#  'Showcard Gothic',
#  'Franklin Gothic Medium',
#  'Bodoni MT',
#  'Yet R',
#  'Lucida Fax',
#  'Niagara Engraved',
#  'Bodoni MT',
#  'Tw Cen MT',
#  'Gadugi',
#  'Mongolian Baiti',
#  'Calibri',
#  'Tw Cen MT Condensed Extra Bold',
#  'Nirmala UI',
#  'Leelawadee UI',
#  'ESRI Conservation',
#  'MoeumT R',
#  'Ink Free',
#  'NanumSquare',
#  'Cambria',
#  'Bodoni MT',
#  'Century Gothic',
#  'Lucida Bright',
#  'Arial',
#  'Century Gothic',
#  'ESRI MilSym 04',
#  'ESRI Oil, Gas, & Water',
#  'Garamond',
#  'OCR A Extended',
#  'Times New Roman',
#  'ESRI NIMA City Graphic PT',
#  'Segoe Script',
#  'Perpetua Titling MT',
#  'Californian FB',
#  'ESRI IGL Font22',
#  'ESRI Hydrants',
#  'Malgun Gothic',
#  'Lucida Sans Typewriter',
#  'Footlight MT Light',
#  'Harmonia Sans W06',
#  'Microsoft JhengHei',
#  'ESRI Weather',
#  'Rockwell',
#  'ESRI Climate & Precipitation',
#  'Palatino Linotype',
#  'Constantia',
#  'Goudy Old Style',
#  'Yu Gothic',
#  'Tw Cen MT',
#  'Colonna MT',
#  'Wingdings',
#  'ESRI Default Marker',
#  'Lucida Fax',
#  'Vladimir Script',
#  'ESRI MilMod 01',
#  'ESRI Cartography',
#  'MS Reference Specialty',
#  'Lucida Fax',
#  'Consolas',
#  'Segoe UI',
#  'Microsoft Tai Le',
#  'Bookman Old Style',
#  'HCR Batang ExtB',
#  'Harlow Solid Italic',
#  'ESRI Meteorological 01',
#  'Segoe UI',
#  'Gill Sans Ultra Bold Condensed',
#  'Lucida Sans Typewriter',
#  'High Tower Text',
#  'Segoe UI',
#  'ESRI ArcPad',
#  'ESRI IGL Font20',
#  'Segoe Script',
#  'ESRI Pipeline US 1',
#  'ESRI MilSym 01',
#  'NanumSquare',
#  'Bodoni MT',
#  'NanumSquare',
#  'ESRI MilMod 02',
#  'Verdana',
#  'Matura MT Script Capitals',
#  'Tahoma',
#  'ESRI Crime Analysis',
#  'Sylfaen',
#  'Baskerville Old Face',
#  'Book Antiqua',
#  'Tw Cen MT Condensed',
#  'Candara',
#  'ESRI MilSym 05',
#  'KoPubBatang Medium',
#  'Bell MT',
#  'Calibri',
#  'Agency FB',
#  'ESRI AMFM Gas',
#  'MHunmin',
#  'Arial',
#  'Candara',
#  'Malgun Gothic',
#  'ESRI US MUTCD 2',
#  'Gill Sans Ultra Bold',
#  'ESRI IGL Font24',
#  'Book Antiqua',
#  'HYGraphic-Medium',
#  'ESRI Business',
#  'Myanmar Text',
#  'Modern No. 20',
#  'Malgun Gothic',
#  'Palace Script MT',
#  'Times New Roman',
#  'Onyx',
#  'Magic R',
#  'HCR Dotum',
#  'Segoe Print',
#  'ESRI North',
#  'HYPost-Light',
#  'Rage Italic',
#  'ESRI Geology',
#  'Berlin Sans FB Demi',
#  'ESRI IGL Font21',
#  'Arial',
#  'Trebuchet MS',
#  'Lucida Sans Typewriter',
#  'MSugiHeulim',
#  'NanumSquare',
#  'Goudy Old Style',
#  'ESRI IGL Font16',
#  'Elephant',
#  'HCR Batang ExtB',
#  'NanumSquare_ac',
#  'Brush Script MT',
#  'Yu Gothic',
#  'Ami R',
#  'Corbel',
#  'Broadway',
#  'Lucida Bright',
#  'New Gulim',
#  'Gill Sans MT Ext Condensed Bold',
#  'Gill Sans MT',
#  'Rockwell Condensed',
#  'NewJumja',
#  'Segoe UI',
#  'ESRI US Forestry 2',
#  'ESRI US MUTCD 1',
#  'Lucida Sans',
#  'ESRI IGL Font25',
#  'Candara',
#  'Lucida Sans',
#  'Tw Cen MT',
#  'Perpetua',
#  'Palatino Linotype',
#  'ESRI Telecom',
#  'SimSun-ExtB',
#  'Corbel',
#  'ESRI MilSym 03',
#  'MS Reference Sans Serif',
#  'Perpetua',
#  'Agency FB',
#  'HYHeadLine-Medium',
#  'Yu Gothic',
#  'Perpetua',
#  'Magneto',
#  'Microsoft New Tai Lue',
#  'Arial',
#  'Lucida Sans',
#  'Algerian',
#  'Candara',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Leelawadee UI',
#  'Poor Richard',
#  'HYGungSo-Bold',
#  'Parchment',
#  'MJemokGothic',
#  'MingLiU-ExtB',
#  'ESRI SDS 1.95 1',
#  'Cambria',
#  'ESRI SDS 2.00 1',
#  'Microsoft YaHei',
#  'HYShortSamul-Medium',
#  'Constantia',
#  'ESRI Geology AGSO 1',
#  'ESRI Shields',
#  'Stencil',
#  'Tw Cen MT',
#  'Monotype Corsiva',
#  'Blackadder ITC',
#  'Sitka Small',
#  'Arial',
#  'Felix Titling',
#  'Old English Text MT',
#  'Calisto MT',
#  'Kristen ITC',
#  'Microsoft Tai Le',
#  'ESRI MilSym 02',
#  'Cambria',
#  'Calibri',
#  'Palatino Linotype',
#  'Century',
#  'MSugiJeong',
#  'Segoe Print',
#  'Pristina',
#  'Corbel',
#  'Garamond',
#  'Calisto MT',
#  'ESRI AMFM Electric',
#  'MGungHeulim',
#  'ESRI Transportation & Civic',
#  'MS Gothic',
#  'Juice ITC',
#  'Sitka Small',
#  'Kunstler Script',
#  'Franklin Gothic Book',
#  'Nirmala UI',
#  'Wingdings 3',
#  'Eras Medium ITC',
#  'ESRI US MUTCD 3',
#  'ESRI SDS 1.95 2',
#  'Lucida Sans Typewriter',
#  'Consolas',
#  'Segoe UI Emoji',
#  'Script MT Bold',
#  'ESRI Geometric Symbols',
#  'Segoe MDL2 Assets',
#  'Gulim',
#  'Georgia',
#  'Bahnschrift',
#  'Californian FB',
#  'Gill Sans MT',
#  'HCR Batang',
#  'Lucida Calligraphy',
#  'Rockwell Extra Bold',
#  'Arial',
#  'Consolas',
#  'HYMyeongJo-Extra',
#  'MBatang',
#  'Bodoni MT',
#  'Calibri',
#  'Gabriola',
#  'Centaur',
#  'HoloLens MDL2 Assets',
#  'Segoe UI',
#  'MV Boli',
#  'Lucida Bright',
#  'MS Outlook',
#  'Century Gothic',
#  'Segoe UI',
#  'Gadugi',
#  'Haettenschweiler',
#  'Batang',
#  'Leelawadee UI',
#  'ESRI Fire Incident NFPA',
#  'Sitka Small',
#  'ESRI Caves 1']

# %%
print(mpl.get_cachedir())
# Out:
# C:\Users\AWEL-KDH\.matplotlib

# %%
sns.set_context("talk")
sns.set_palette("Set2")
sns.set_style("white")

# %%
mine=pd.read_csv('폐광.csv', encoding='cp949')

# %%
#그래프 그리기
plt.figsize=(40,10)
plt.bar(mine['지역'], mine['광산수'])
plt.ylim(0, 350)
plt.ylabel("폐광수", fontsize=24, labelpad=24, weight='bold')
# Out:
# Text(0, 0.5, '폐광수')
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49436 (\N{HANGUL SYLLABLE SEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50872 (\N{HANGUL SYLLABLE UL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44305 (\N{HANGUL SYLLABLE GWANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51452 (\N{HANGUL SYLLABLE JU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48512 (\N{HANGUL SYLLABLE BU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49328 (\N{HANGUL SYLLABLE SAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49464 (\N{HANGUL SYLLABLE SE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51333 (\N{HANGUL SYLLABLE JONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52380 (\N{HANGUL SYLLABLE CEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48513 (\N{HANGUL SYLLABLE BUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52649 (\N{HANGUL SYLLABLE CUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54224 (\N{HANGUL SYLLABLE PYE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\AWEL-KDH\anaconda3\envs\py39\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
