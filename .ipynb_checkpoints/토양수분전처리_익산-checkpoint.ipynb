# %% [markdown]
# # 센서자동화 짜기...

# %% [markdown]
# 1) 우선 하나의 파일 작업을 만든다
# 2) 그걸로 클래스화 하고..
# 3) 폴더내에 넣으면 알아서 전처리한거 output 되게
# 4) 그래프는 파이썬으로 처리

# %% [markdown]
# # import

# %%
import pandas as pd
import numpy as np
import os
import datetime

# %%
# # 폴더내 파일 이름 리스트 가져오기 (이거 한다음에 인덱싱해서 불러오면 되겠다)
# import os
# file_list = os.listdir('경로')
# file_lsit

# %%
df = pd.read_csv("z6-20060(z6-20060)-1680409899.csv", encoding="cp949")

# 행열 삭제
df.drop([0,1,2,3], axis=0, inplace=True)
df.drop(df.columns[[2,4,6,8,10,12,13,14,15,16]], axis=1, inplace=True)
df['날짜']=pd.to_datetime(df["z6-20060"], format='%Y-%m-%d %H:%M:%S')
df['년']=df['날짜'].dt.year
df['월']=df['날짜'].dt.month
df['일']=df['날짜'].dt.day
# df['시']=df['날짜'].dt.hour
# df['분']=df['날짜'].dt.minute
# df['초']=df['날짜'].dt.second

df.drop(df.columns[[0]], axis=1, inplace=True)
df=df[['년', '월', '일','Port1', 'Port2', 'Port3', 'Port4', 'Port5', 'Port6']]
# df=df[['년', '월', '일', '시', '분', '초', 'Port1', 'Port2', 'Port3', 'Port4', 'Port5', 'Port6']]
df
# Out:
#          년  월   일  Port1  Port2  Port3   Port4  Port5  Port6
# 4     2023  3  21  -41.4  -35.3  -43.5   -52.6  -40.3    -43
# 5     2023  3  21  -41.5  -35.4  -43.5   -52.6  -40.4    -43
# 6     2023  3  21  -41.6  -35.4  -43.5   -52.6  -40.4    -43
# 7     2023  3  21  -41.8  -35.4  -43.5   -52.7  -40.3    -43
# 8     2023  3  21    -42  -35.5  -43.5   -52.7  -40.3  -43.1
# ...    ... ..  ..    ...    ...    ...     ...    ...    ...
# 1692  2023  4   2    -80  -57.1  -92.5  -141.6  -88.5  -73.4
# 1693  2023  4   2  -79.9  -57.1  -92.8    -142  -88.9  -73.4
# 1694  2023  4   2  -79.7  -57.2  -93.1    -142  -89.2  -73.6
# 1695  2023  4   2  -79.7  -57.3  -93.3    -142  -89.5  -73.7
# 1696  2023  4   2  -79.7  -57.5  -93.3  -142.6  -89.8  -73.9
#
# [1693 rows x 9 columns]

# %%
df.groupby(['년','월', '일']).mean()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_22088\860896993.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['년','월', '일']).mean()
# Empty DataFrame
# Columns: []
# Index: [(2023, 3, 21), (2023, 3, 22), (2023, 3, 23), (2023, 3, 24), (2023, 3, 25), (2023, 3, 26), (2023, 3, 27), (2023, 3, 28), (2023, 3, 29), (2023, 3, 30), (2023, 3, 31), (2023, 4, 1), (2023, 4, 2)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#스타일 설정
sns.set_context("talk")
sns.set_palette("Set2")
sns.set_style("white")

# %%
#폰트 설정
import matplotlib.font_manager as fm
import numpy as np

plt.rcParams['font.family'] = 'Times New Roman'

# fig, axs = plt.subplots(1,1, figsize=(40,20))

# plt.scatter(df['월'], df['Port1'])
# plt.set_yticks(np.arange(0, -10000, -500))
# plt.set_ylabel("강수량(mm)", fontsize=24, labelpad=24, weight='bold')

# %%
import numpy as np
